# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

# %%
results_1 = model.train(
    
    data="dataset/data.yaml",
    epochs=30,
    batch=32,
    imgsz=640,

    augment=True,
    auto_augment=None,
    degrees=0.15,      
    translate=0.0,      
    scale=0.0,
    shear=0.0,       
    perspective=0.0,  
    flipud=0.5,       
    fliplr=0.5,       
    mosaic=0.0,       
    mixup=0.0,        
    copy_paste=0.0,   
    hsv_h=0.0,        
    hsv_s=0.3,       
    hsv_v=0.3,       
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.203 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.173 🚀 Python-3.12.8 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...
